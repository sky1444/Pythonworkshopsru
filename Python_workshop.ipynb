# %% [markdown]
# <a href="https://colab.research.google.com/github/sky1444/Pythonworkshopsru/blob/main/Python_workshop.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ***Day-1***

# %%
import keyword
print("standard keyword=", len(keyword.kwlist))
print("soft keyword=", keyword.softkwlist)
print("all keyword=", keyword.kwlist)
# Out:
# standard keyword= 35
# soft keyword= ['_', 'case', 'match', 'type']
# all keyword= ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
x=5
y="Jhon"
z=3.0
print(x)
print(y)
print(z)
# Out:
# 5
# Jhon
# 3.0

# %%
print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>

# %%
y1=2
print(y1)
print(type(y1))
y2=float(y1)
print(y2)
print(type(y2))
y3=str(y1)
print(y3)
print(type(y3))
# Out:
# 2
# <class 'int'>
# 2.0
# <class 'float'>
# 2
# <class 'str'>

# %%
y1=int(2)
y2=float(2)
y3=str(2)
print(y1)
print(y2)
print(y3)
print(type(y1))
print(type(y2))
print(type(y3))
# Out:
# 2
# 2.0
# 2
# <class 'int'>
# <class 'float'>
# <class 'str'>

# %%
c=50
d=float(c)
print(type(d))
# Out:
# <class 'float'>

# %%
a=2
A="Shravan"
print(a)
print(A)
# Out:
# 2
# Shravan

# %%
myname="Shravan"
my_dept="ME"
_my_university="SRU"
myLoc="Warangal"
MYLOC="Telangana"
mydept2="MSE"
print(myname)
print(my_dept)
print(_my_university)
print(myLoc)
print(MYLOC)
print(mydept2)
# Out:
# Shravan
# ME
# SRU
# Warangal
# Telangana
# MSE

# %%
a=input("Enter value of a")
b=input("Enter value of b")
a=int(a)
b=int(b)
print("==========")
print("Sample Calculator")
print("==========")
print("Addition=",a+b)
print("Sub=",a-b)
print("Mul=",a*b)
print("Div=",a/b)
print("Rem=",a%b)
print("========")
# Out:
# Enter value of a20
# Enter value of b10
# ...
# Sample Calculator
# ...
# Addition= 30
# Sub= 10
# Mul= 200
# Div= 2.0
# Rem= 0
# ...

# %% [markdown]
# # ***Day 2***
